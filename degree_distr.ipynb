# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# ROUTES - DAYTIME
df = pd.read_csv('route_degrees_daytime.csv',header=0)

# %%
mu = np.mean(df['degree'])

fig = plt.figure()
hist, bins, patches = plt.hist(df['degree'], bins=11, density=True)
plt.vlines(mu,0,0.018, colors="black") #It gives the same result as the sql query

fig.patch.set_facecolor('white')
plt.legend((f'<k>={round(mu,2)}','Degree distribution'))
plt.xlabel('k')
plt.ylabel('p(k)')
plt.grid()
plt.title('Degree distribution of daytime BpPT routes Network')
plt.savefig('route_degrees_daytime.png')

# %%
# ROUTES - NIGHTTIME
df = pd.read_csv('route_degrees_nighttime.csv',header=0)

# %%
mu = np.mean(df['degree'])

fig = plt.figure()
hist, bins, patches = plt.hist(df['degree'], bins=5, density=True)
plt.vlines(np.mean(df['degree']),0,0.06, colors="black") #It gives the same result as the sql query

fig.patch.set_facecolor('white')
plt.legend((f'<k>={round(mu,2)}','Degree distribution'))
plt.xlabel('k')
plt.ylabel('p(k)')
plt.grid()
plt.title('Degree distribution of nighttime BpPT routes Network')
plt.savefig('route_degrees_nighttime.png')

# %%
# STOPS - DAYTIME
df = pd.read_csv('stop_degrees_daytime.csv',header=0)

# %%
mu = np.mean(df['degree'])

fig = plt.figure()
hist, bins, patches = plt.hist(df['degree'], bins=50, density=True)
plt.vlines(np.mean(df['degree']),0,0.015, colors="black") #It gives the same result as the sql query

fig.patch.set_facecolor('white')
plt.legend((f'<k>={round(mu,2)}','Degree distribution'))
plt.xlabel('k')
plt.ylabel('p(k)')
plt.grid()
plt.title('Degree distribution of BpPT stops Network')
plt.savefig('stop_degrees_daytime.png')
#This looks scale-free. Further investigation is needed.
